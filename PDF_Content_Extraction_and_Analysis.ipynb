# %% [markdown]
# <a href="https://colab.research.google.com/github/aa18622/Projects-portfolio/blob/main/PDF_Content_Extraction_and_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pypdf
from pypdf import PdfReader

# %%
reader = PdfReader('YOLO.pdf')
page = reader.pages[0]

# Print the number of pages in the PDF
print(f"There are {len(reader.pages)} Pages")
# Out:
# There are 11 Pages

# %%
# EXTRACT TEXT

reader = PdfReader("YOLO.pdf")

# Get the first page (index 0)
page = reader.pages[0]
# Use extract_text() to get the text of the page
print(page.extract_text())

# Go through every page and get the text
for i in range(len(reader.pages)):
  page = reader.pages[i]
  print(page.extract_text())
# Out:
# The EUROCALL Review, Volume 25, No. 2, September 2017
#
#  18
# Research paper
#
# A look at advanced learners’ use of mobile devices for
# English language study: Insights from interview data
# Mariusz Kruk
# University of Zielona Gora, Poland
# ______________________________________________________________
# mkruk @ uz.zgora.pl
#
# Abstract
# The paper discusses the results of a study which explored advanced learners of English
# engagement with their mobile devices to develop learning experiences that meet their
# needs and goals as foreign language learners. The data were collected from 20 students
# by means of a semi -structured interview. The gathered data were subjected to
# qualitative and quantitative analysis. The results of the study demonstrated that , on the
# one hand , some subjects manifested heightened awareness relating to the
# advantageous role of mobile devices in their learning endeavors, their ability to reach
# ...

# %%
for i in page.images:
    with open(i.name, "wb") as f:
        f.write(i.data)

# %%
# !pip install pdfplumber
import pdfplumber

# %%
with pdfplumber.open('YOLO.pdf') as f:
  for i in f.pages:
    print(i.extract_tables())
# Out:
# [[['Research paper'], [''], ['A look at advanced learners’ use of mobile devices for'], ['English language study: Insights from interview data'], ['Mariusz Kruk'], ['University of Zielona Gora, Poland'], ['______________________________________________________________'], ['mkruk @ uz.zgora.pl'], [''], ['Abstract'], ['The paper discusses the results of a study which explored advanced learners of English'], ['engagement with their mobile devices to develop learning experiences that meet their'], ['needs and goals as foreign language learners. The data were collected from 20 students'], ['by means of a semi-structured interview. The gathered data were subjected to'], ['qualitative and quantitative analysis. The results of the study demonstrated that, on the'], ['one hand, some subjects manifested heightened awareness relating to the'], ['advantageous role of mobile devices in their learning endeavors, their ability to reach'], ['for suitable tools and retrieve necessary information so a
# ...

# %%
# !pip install pymupdf
import fitz

# %%
doc = fitz.open('YOLO.pdf')
print(doc.page_count)
# Out:
# 11

# %%
print(doc.metadata)
# Out:
# {'format': 'PDF 1.6', 'title': '', 'author': 'agimeno', 'subject': '', 'keywords': '', 'creator': 'Microsoft® Word 2016', 'producer': 'Microsoft® Word 2016', 'creationDate': "D:20180305094357+01'00'", 'modDate': "D:20180312102410-04'00'", 'trapped': '', 'encryption': None}

# %%
page = doc.load_page(0)
print(page.get_text())
# Out:
# The EUROCALL Review, Volume 25, No. 2, September 2017
#
# 18
# Research paper
#
# A look at advanced learners’ use of mobile devices for
# English language study: Insights from interview data
# Mariusz Kruk
# University of Zielona Gora, Poland
# ______________________________________________________________
# mkruk @ uz.zgora.pl
#
# Abstract
# The paper discusses the results of a study which explored advanced learners of English
# engagement with their mobile devices to develop learning experiences that meet their
# needs and goals as foreign language learners. The data were collected from 20 students
# by means of a semi-structured interview. The gathered data were subjected to
# qualitative and quantitative analysis. The results of the study demonstrated that, on the
# one hand, some subjects manifested heightened awareness relating to the
# advantageous role of mobile devices in their learning endeavors, their ability to reach
# ...

# %%
pic = page.get_pixmap()
pic.save(f"page_{page.number}.png")

# %%
links = page.get_links()
print(links)
# Out:
# [{'kind': 2, 'xref': 85, 'from': Rect(245.60000610351562, 224.65997314453125, 349.70001220703125, 241.4599609375), 'uri': 'mailto:mkruk@uz.zgora.pl', 'id': ''}]
